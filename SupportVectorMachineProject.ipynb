# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../Course Materials/DATA/wine_fraud.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         6497 non-null   float64
#  1   volatile acidity      6497 non-null   float64
#  2   citric acid           6497 non-null   float64
#  3   residual sugar        6497 non-null   float64
#  4   chlorides             6497 non-null   float64
#  5   free sulfur dioxide   6497 non-null   float64
#  6   total sulfur dioxide  6497 non-null   float64
#  7   density               6497 non-null   float64
#  8   pH                    6497 non-null   float64
#  9   sulphates             6497 non-null   float64
#  10  alcohol               6497 non-null   float64
#  11  quality               6497 non-null   object
#  12  type                  6497 non-null   object
# dtypes: float64(11), object(2)
# memory usage: 660.0+ KB

# %%
df.describe().T
# Out:
#                        count        mean        std      min       25%  \
# fixed acidity         6497.0    7.215307   1.296434  3.80000   6.40000
# volatile acidity      6497.0    0.339666   0.164636  0.08000   0.23000
# citric acid           6497.0    0.318633   0.145318  0.00000   0.25000
# residual sugar        6497.0    5.443235   4.757804  0.60000   1.80000
# chlorides             6497.0    0.056034   0.035034  0.00900   0.03800
# free sulfur dioxide   6497.0   30.525319  17.749400  1.00000  17.00000
# total sulfur dioxide  6497.0  115.744574  56.521855  6.00000  77.00000
# density               6497.0    0.994697   0.002999  0.98711   0.99234
# pH                    6497.0    3.218501   0.160787  2.72000   3.11000
# sulphates             6497.0    0.531268   0.148806  0.22000   0.43000
# alcohol               6497.0   10.491801   1.192712  8.00000   9.50000
#
#                             50%        75%        max
# fixed acidity           7.00000    7.70000   15.90000
# ...

# %%
df['quality'].unique()
# Out:
# array(['Legit', 'Fraud'], dtype=object)

# %%
sns.countplot(data = df,x='quality')
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
df['quality'].value_counts()
# Out:
# quality
# Legit    6251
# Fraud     246
# Name: count, dtype: int64

# %%
sns.countplot(data = df,x='type',hue = 'quality')
# Out:
# <Axes: xlabel='type', ylabel='count'>

# %%
red = df[df['type']=='red']

# %%
red
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
red['quality'].unique()
# Out:
# array(['Legit', 'Fraud'], dtype=object)

# %%
red_fraud = red[red['quality'] == 'Fraud']

# %%
len(red_fraud)/len(red)*100
# Out:
# 3.9399624765478425

# %%
white = df[df['type']=='white']

# %%
white_fraud = white[white['quality'] == 'Fraud']

# %%
len(white_fraud)/len(white)*100
# Out:
# 3.7362188648427925

# %%
df['new_quality'] = df['quality'].map({'Legit':0,'Fraud':1})

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type  new_quality
# 0      9.4   Legit  red            0
# ...

# %%
df.drop(['quality','type'],axis=1).corr()['new_quality']
# Out:
# fixed acidity           0.021794
# volatile acidity        0.151228
# citric acid            -0.061789
# residual sugar         -0.048756
# chlorides               0.034499
# free sulfur dioxide    -0.085204
# total sulfur dioxide   -0.035252
# density                 0.016351
# pH                      0.020107
# sulphates              -0.034046
# alcohol                -0.051141
# new_quality             1.000000
# Name: new_quality, dtype: float64

# %%
plt.figure(figsize = (8,6),dpi=150)
df.drop(['quality','type'],axis=1).corr()['new_quality'][:-1].sort_values().plot(kind='bar')
# Out:
# <Axes: >

# %%
sns.clustermap(df.drop(['quality','type'],axis=1).corr())

# %%
#df = df.drop('quality',axis=1)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type  new_quality
# 0      9.4   Legit  red            0
# ...

# %%
df_ = pd.get_dummies(df,drop_first=True,dtype = 'int')

# %%
df_.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  new_quality  quality_Legit  type_white
# ...

# %%
df_ = df_.drop('new_quality',axis=1)

# %%
df_.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality_Legit  type_white
# 0      9.4              1           0
# ...

# %%
df_['quality_Legit'] = df['quality']

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# ...

# %%
df_.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality_Legit  type_white
# 0      9.4         Legit           0
# ...

# %%
X = df_.drop('quality_Legit',axis=1)

# %%
y = df_['quality_Legit']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaled_x_train = scaler.fit_transform(X_train)

# %%
scaled_x_test = scaler.transform(X_test)

# %%
from sklearn.svm import SVC

# %%
svc = SVC(class_weight='balanced')

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid = {'C': [0.001, 0.01, 0.1, 0.5, 1],
            'gamma': ['scale', 'auto']}

# %%
grid_model = GridSearchCV(svc,param_grid)

# %%
grid_model
# Out:
# GridSearchCV(estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'gamma': ['scale', 'auto']})

# %%
grid_model.get_params()
# Out:
# {'cv': None,
#  'error_score': nan,
#  'estimator__C': 1.0,
#  'estimator__break_ties': False,
#  'estimator__cache_size': 200,
#  'estimator__class_weight': 'balanced',
#  'estimator__coef0': 0.0,
#  'estimator__decision_function_shape': 'ovr',
#  'estimator__degree': 3,
#  'estimator__gamma': 'scale',
#  'estimator__kernel': 'rbf',
#  'estimator__max_iter': -1,
#  'estimator__probability': False,
#  'estimator__random_state': None,
#  'estimator__shrinking': True,
#  'estimator__tol': 0.001,
#  'estimator__verbose': False,
#  'estimator': SVC(class_weight='balanced'),
#  'n_jobs': None,
#  'param_grid': {'C': [0.001, 0.01, 0.1, 0.5, 1], 'gamma': ['scale', 'auto']},
#  'pre_dispatch': '2*n_jobs',
#  'refit': True,
#  'return_train_score': False,
#  'scoring': None,
#  'verbose': 0}

# %%
grid_model.fit(scaled_x_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'gamma': ['scale', 'auto']})

# %%
from sklearn.metrics import classification_report,ConfusionMatrixDisplay,confusion_matrix

# %%
grid_model.best_estimator_
# Out:
# SVC(C=1, class_weight='balanced', gamma='auto')

# %%
grid_model.best_estimator_.get_params()
# Out:
# {'C': 1,
#  'break_ties': False,
#  'cache_size': 200,
#  'class_weight': 'balanced',
#  'coef0': 0.0,
#  'decision_function_shape': 'ovr',
#  'degree': 3,
#  'gamma': 'auto',
#  'kernel': 'rbf',
#  'max_iter': -1,
#  'probability': False,
#  'random_state': None,
#  'shrinking': True,
#  'tol': 0.001,
#  'verbose': False}

# %%
y_pred = grid_model.predict(scaled_x_test)

# %%
cm = confusion_matrix(y_pred,y_test)

# %%
cm
# Out:
# array([[ 17,  92],
#        [ 10, 531]], dtype=int64)

# %%
ConfusionMatrixDisplay.from_predictions(y_pred,y_test)

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#        Fraud       0.63      0.16      0.25       109
#        Legit       0.85      0.98      0.91       541
#
#     accuracy                           0.84       650
#    macro avg       0.74      0.57      0.58       650
# weighted avg       0.81      0.84      0.80       650

# %% [markdown]
# ## Model Evaluation

# %%
df = pd.read_csv('../Course Materials/DATA/wine_fraud.csv')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality type
# 0      9.4   Legit  red
# 1      9.8   Legit  red
# ...

# %%
df['type'] = pd.get_dummies(df['type'],drop_first=True,dtype='int')

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol quality  type
# 0      9.4   Legit     0
# 1      9.8   Legit     0
# ...

# %%
X = df.drop('quality',axis=1)
y = df['quality']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, random_state=101)

# %%
scaled_X_train = scaler.fit_transform(X_train)
scaled_X_test = scaler.transform(X_test)

# %%
svc_new = SVC(class_weight='balanced')

# %%
param_grid = {'C':[0.001,0.01,0.1,0.5,1],'gamma':['scale','auto']}
grid = GridSearchCV(svc,param_grid)

# %%
grid.fit(scaled_X_train,y_train)
# Out:
# GridSearchCV(estimator=SVC(class_weight='balanced'),
#              param_grid={'C': [0.001, 0.01, 0.1, 0.5, 1],
#                          'gamma': ['scale', 'auto']})

# %%
grid.best_params_
# Out:
# {'C': 1, 'gamma': 'auto'}

# %%
grid_pred = grid.predict(scaled_X_test)

# %%
confusion_matrix(y_test,grid_pred)
# Out:
# array([[ 17,  10],
#        [ 92, 531]], dtype=int64)

# %%
CVM = ConfusionMatrixDisplay.from_predictions(y_test,grid_pred)

# %%
CVM = ConfusionMatrixDisplay.from_predictions(grid_pred,y_test)
